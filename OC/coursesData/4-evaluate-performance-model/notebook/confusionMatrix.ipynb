# %% [markdown]
# You use a confusion matrix on multiple models to evaluate the performance of each.
#
# [Youtube sample](https://www.youtube.com/watch?v=vP06aMoz4v8&t=0s)

# %% [markdown]
# <img src="attachment:99a75685-584e-4ae7-8999-9a4a155a3b2e.png" width="600"/>

# %% [markdown]
# ## Sensitivity

# %% [markdown]
# What percentage of patients with heart disease were correctly identified
# Sensitivity = True positives / (True positives + False negatives)

# %% [markdown]
# <img src="attachment:7c98f650-4284-449f-835e-935e5ad8c810.png" width="600"/>

# %% [markdown]
# <img src="attachment:7dd8ccf0-b47b-4822-89bf-2fe713d93667.png" width="600"/>

# %% [markdown]
# ## Specificity

# %% [markdown]
# What percentage of patients without heart disease were correctly identified
# Sensibility = True negatives / (True negatives + False positives)

# %% [markdown]
# <img src="attachment:93dda38f-5ef6-4e42-aa2a-16dd0b0cf8fb.png" width="600"/>
# <img src="attachment:a734b235-eb6b-4212-91d2-54e1ee55d854.png" width="600"/>

# %% [markdown]
# ## Multiple rows

# %% [markdown]
# Calculate Sensitivity & Specificity on multiple rows
#
# <img src="attachment:87eafa07-7ec6-4f99-9122-5cdf33afe3e4.png" width="600"/>
#
# <img src="attachment:e4ee5b76-5d28-42ac-9c13-d2610ec0d5c6.png" width="600"/>
#
# <img src="attachment:ad661ee0-c0b3-4e15-ae41-b82a01b847b4.png" width="600"/>
