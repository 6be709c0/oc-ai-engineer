# %% [markdown]
# ## Modelisation with UNET Mini

# %%
import sys  
sys.path.insert(0, './scripts')

# Import librairies, configs, helper functions
from helpers import *

config = base_config_resized

# config["use_saved_model_path"] = "./model_v4_full_cat_8.h5"
config["val_sample_nb"] = 100
config["train_sample_nb"] = 400
config["epoch"] = 4

n = NotebookProcessor(config)
# Out:
# <h1 style="padding:0;margin:0;"><b>CONFIG USED</b></h1>
# {
#     "width": 256,
#     "height": 128,
#     "classes": 8,
#     "epoch": 4,
#     "batch_size": 3,
#     "learning_rate": 0.001,
#     "train_sample_nb": 400,
#     "val_sample_nb": 100,
#     "use_saved_model_path": "",
#     "gtFine_path": "./data/P8_Cityscapes_gtFine_trainvaltest.zip",
#     "leftImg8bit_path": "./data/P8_Cityscapes_leftImg8bit_trainvaltest.zip",
#     "data_path": "./data/gtFine"
# }
#
# Dataset already exist, skip downloading: ./data/P8_Cityscapes_gtFine_trainvaltest.zip
# Dataset already exist, skip downloading: ./data/P8_Cityscapes_leftImg8bit_trainvaltest.zip
#
# - Sampling the training dataset from 2975 to 400.
#
# - Sampling the validation dataset from 500 to 100.
# 2024-02-26 16:57:37.360332: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2
# 2024-02-26 16:57:37.360349: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 24.00 GB
# 2024-02-26 16:57:37.360353: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 8.00 GB
# 2024-02-26 16:57:37.360382: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 16:57:37.360401: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# ## Model definition

# %% [markdown]
# UNET is lorem ipsum

# %% [markdown]
# ## Model creation

# %%
def conv_block(input_tensor, num_filters, dropout_rate=0.1):  
    x = Conv2D(num_filters, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(input_tensor)  
    x = BatchNormalization()(x)  # Adding batch normalization  
    x = Dropout(dropout_rate)(x)  
    x = Conv2D(num_filters, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(x)  
    x = BatchNormalization()(x)  # Adding batch normalization  
    return x  
  
def create_model(n_classes, img_width, img_height, img_channels):    
    # Load VGG16 as the encoder with pretrained ImageNet weights  
    base_vgg16 = VGG16(include_top=False, weights='imagenet', input_shape=(img_height, img_width, img_channels))  
      
    # Freeze the layers of VGG16  
    for layer in base_vgg16.layers:  
        layer.trainable = False  
      
    # Encoder - take the outputs of the VGG16 layers to create the contracting path  
    s1 = base_vgg16.get_layer("block1_conv2").output  # 64 filters  
    s2 = base_vgg16.get_layer("block2_conv2").output  # 128 filters  
    s3 = base_vgg16.get_layer("block3_conv3").output  # 256 filters  
    s4 = base_vgg16.get_layer("block4_conv3").output  # 512 filters  
    c5 = base_vgg16.get_layer("block5_conv3").output  # 512 filters, this acts as the bridge  
  
    # Start from bottom and go up, using U-Net's expansive path  
    u6 = Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(c5)    
    u6 = concatenate([u6, s4])    
    c6 = conv_block(u6, 512)   
      
    u7 = Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(c6)    
    u7 = concatenate([u7, s3])    
    c7 = conv_block(u7, 256)    
      
    u8 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c7)    
    u8 = concatenate([u8, s2])    
    c8 = conv_block(u8, 128)    
      
    u9 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c8)    
    u9 = concatenate([u9, s1])    
    c9 = conv_block(u9, 64)    
  
    outputs = Conv2D(n_classes, (1, 1), activation='softmax')(c9)    
      
    model = Model(inputs=[base_vgg16.input], outputs=[outputs])  
      
    return model

# %% [markdown]
# ## Model Stats

# %%
model = create_model(n_classes=config["classes"], img_width=config["width"], img_height=config["height"], img_channels=3)
n.set_model(model)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 256, 3)]        0         []
#
#  block1_conv1 (Conv2D)       (None, 128, 256, 64)         1792      ['input_1[0][0]']
#
#  block1_conv2 (Conv2D)       (None, 128, 256, 64)         36928     ['block1_conv1[0][0]']
#
#  block1_pool (MaxPooling2D)  (None, 64, 128, 64)          0         ['block1_conv2[0][0]']
#
#  block2_conv1 (Conv2D)       (None, 64, 128, 128)         73856     ['block1_pool[0][0]']
#
#  block2_conv2 (Conv2D)       (None, 64, 128, 128)         147584    ['block2_conv1[0][0]']
#
#  block2_pool (MaxPooling2D)  (None, 32, 64, 128)          0         ['block2_conv2[0][0]']
#
#  block3_conv1 (Conv2D)       (None, 32, 64, 256)          295168    ['block2_pool[0][0]']
#
#  block3_conv2 (Conv2D)       (None, 32, 64, 256)          590080    ['block3_conv1[0][0]']
#
#  block3_conv3 (Conv2D)       (None, 32, 64, 256)          590080    ['block3_conv2[0][0]']
#
#  block3_pool (MaxPooling2D)  (None, 16, 32, 256)          0         ['block3_conv3[0][0]']
#
#  block4_conv1 (Conv2D)       (None, 16, 32, 512)          1180160   ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)       (None, 16, 32, 512)          2359808   ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)       (None, 16, 32, 512)          2359808   ['block4_conv2[0][0]']
#
#  block4_pool (MaxPooling2D)  (None, 8, 16, 512)           0         ['block4_conv3[0][0]']
#
#  block5_conv1 (Conv2D)       (None, 8, 16, 512)           2359808   ['block4_pool[0][0]']
#
#  block5_conv2 (Conv2D)       (None, 8, 16, 512)           2359808   ['block5_conv1[0][0]']
#
#  block5_conv3 (Conv2D)       (None, 8, 16, 512)           2359808   ['block5_conv2[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 16, 32, 512)          1049088   ['block5_conv3[0][0]']
#  anspose)
#
#  concatenate (Concatenate)   (None, 16, 32, 1024)         0         ['conv2d_transpose[0][0]',
#                                                                      'block4_conv3[0][0]']
#
#  conv2d (Conv2D)             (None, 16, 32, 512)          4719104   ['concatenate[0][0]']
#
#  batch_normalization (Batch  (None, 16, 32, 512)          2048      ['conv2d[0][0]']
#  Normalization)
#
#  dropout (Dropout)           (None, 16, 32, 512)          0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 16, 32, 512)          2359808   ['dropout[0][0]']
#
#  batch_normalization_1 (Bat  (None, 16, 32, 512)          2048      ['conv2d_1[0][0]']
#  chNormalization)
#
#  conv2d_transpose_1 (Conv2D  (None, 32, 64, 256)          524544    ['batch_normalization_1[0][0]'
#  Transpose)                                                         ]
#
#  concatenate_1 (Concatenate  (None, 32, 64, 512)          0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'block3_conv3[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 32, 64, 256)          1179904   ['concatenate_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 32, 64, 256)          1024      ['conv2d_2[0][0]']
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 32, 64, 256)          0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_3 (Conv2D)           (None, 32, 64, 256)          590080    ['dropout_1[0][0]']
#
#  batch_normalization_3 (Bat  (None, 32, 64, 256)          1024      ['conv2d_3[0][0]']
#  chNormalization)
#
#  conv2d_transpose_2 (Conv2D  (None, 64, 128, 128)         131200    ['batch_normalization_3[0][0]'
#  Transpose)                                                         ]
#
#  concatenate_2 (Concatenate  (None, 64, 128, 256)         0         ['conv2d_transpose_2[0][0]',
#  )                                                                   'block2_conv2[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 64, 128, 128)         295040    ['concatenate_2[0][0]']
#
#  batch_normalization_4 (Bat  (None, 64, 128, 128)         512       ['conv2d_4[0][0]']
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 64, 128, 128)         0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv2d_5 (Conv2D)           (None, 64, 128, 128)         147584    ['dropout_2[0][0]']
#
#  batch_normalization_5 (Bat  (None, 64, 128, 128)         512       ['conv2d_5[0][0]']
#  chNormalization)
#
#  conv2d_transpose_3 (Conv2D  (None, 128, 256, 64)         32832     ['batch_normalization_5[0][0]'
#  Transpose)                                                         ]
#
#  concatenate_3 (Concatenate  (None, 128, 256, 128)        0         ['conv2d_transpose_3[0][0]',
#  )                                                                   'block1_conv2[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 128, 256, 64)         73792     ['concatenate_3[0][0]']
#
#  batch_normalization_6 (Bat  (None, 128, 256, 64)         256       ['conv2d_6[0][0]']
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 128, 256, 64)         0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv2d_7 (Conv2D)           (None, 128, 256, 64)         36928     ['dropout_3[0][0]']
#
#  batch_normalization_7 (Bat  (None, 128, 256, 64)         256       ['conv2d_7[0][0]']
#  chNormalization)
#
#  conv2d_8 (Conv2D)           (None, 128, 256, 8)          520       ['batch_normalization_7[0][0]'
#                                                                     ]
#
# ==================================================================================================
# Total params: 25862792 (98.66 MB)
# Trainable params: 11144264 (42.51 MB)
# Non-trainable params: 14718528 (56.15 MB)
# __________________________________________________________________________________________________

# %%
n.model_fit()
# Out:
# Train steps: 133
# Balidation steps: 33
#
# ---------------------
#
#
# Epoch 1/4
# 2024-02-26 16:57:39.257369: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 133/133 [==============================] - 38s 241ms/step - loss: 0.7118 - accuracy: 0.7854 - val_loss: 1.9007 - val_accuracy: 0.6848
# Epoch 2/4
# 133/133 [==============================] - 37s 252ms/step - loss: 0.5400 - accuracy: 0.8341 - val_loss: 1.2581 - val_accuracy: 0.6898
# Epoch 3/4
# 133/133 [==============================] - 32s 243ms/step - loss: 0.4928 - accuracy: 0.8466 - val_loss: 0.4887 - val_accuracy: 0.8506
# Epoch 4/4
# 133/133 [==============================] - 32s 242ms/step - loss: 0.4623 - accuracy: 0.8540 - val_loss: 0.6414 - val_accuracy: 0.8214
#
# Model trained!

# %%
n.model_save("model_delete.h5")
# Out:
# /Users/m/dev/6be709c0/oc-ai-engineer/OC/P8/output/venv/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
display_loss_and_accuracy(n.model_fit_history)

# %%
n.model_predict_with_display_and_accuracy(n.img["val"][3],n.mask["val"][3])
# Out:
# 1/1 [==============================] - 0s 275ms/step
# Accuracy: 94.07%

# %% [markdown]
# ## Model Inference

# %%
n.model_predict_with_display(n.img["val"][3])
# Out:
# 1/1 [==============================] - 0s 14ms/step
